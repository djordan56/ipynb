# %%
David Jordan
students_gpas
This program takes student names and gpas, checks to see if they made the Dean's List or Honor Roll.
This program will stop processing when the user enters 'ZZZ' as the last name.

# %%
while True:
    last_name = input("Enter student's last name (or 'ZZZ' to quit): ")

    if last_name == "ZZZ":
        print("Exiting program.")
|       break

    first_name = input("Enter student's first name: ")
    gpa = float(input("Enter student's GPA: "))

    if gpa >= 3.5:
        print(f"{first_name} {last_name} has made the Dean's List.")
    elif gpa >= 3.25:
        print(f"{first_name} {last_name} has made the Honor Roll.")

    print()
# Out:
# Enter student's last name (or 'ZZZ' to quit):  Ellis
# Enter student's first name:  Sydney
# Enter student's GPA:  3.6
# Sydney Ellis has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  Flannery
# Enter student's first name:  Odell
# Enter student's GPA:  3.35
# Odell Flannery has made the Honor Roll.
# Enter student's last name (or 'ZZZ' to quit):  Malone
# Enter student's first name:  Devan
# Enter student's GPA:  4.0
# Devan Malone has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  Payton
# Enter student's first name:  Ashton
# Enter student's GPA:  3.43
# Ashton Payton has made the Honor Roll.
# Enter student's last name (or 'ZZZ' to quit):  Campbell
# Enter student's first name:  Shae
# Enter student's GPA:  3.8
# Shae Campbell has made the Dean's List.
# Enter student's last name (or 'ZZZ' to quit):  Diggs
# Enter student's first name:  Lacy
# Enter student's GPA:  4.0
# Lacy Diggs has made the Dean's List.
